# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkST0151ENSkillsNetwork20531532-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Cas de projet : Données sur le logement à Boston**

# %% [markdown]
# ## Scénario du projet
#
# Scénario du projet : Vous êtes Data Scientist au sein d'une agence de logement à Boston MA. On vous a donné accès à un ensemble de données antérieures sur les prix des logements dérivées du service de recensement américain afin de présenter des idées à la direction. Sur la base de votre expérience en statistiques, quelles informations pouvez-vous leur fournir pour les aider à prendre une décision éclairée ? Les cadres supérieurs aimeraient obtenir des informations sur les points suivants.
#
# *   Existe-t-il une différence significative dans la valeur médiane des maisons bordées par la rivière Charles ou non ?
# *   Existe-t-il une différence entre les valeurs médianes des maisons de chaque proportion de logements occupés par leur propriétaire et construits avant 1940 ?
# *   Peut-on conclure qu'il n'y a pas de relation entre les concentrations d'oxyde nitrique et la proportion d'hectares de commerces autres que de détail par ville ?
# *   Quel est l'impact d'une distance pondérée supplémentaire par rapport aux cinq centres d'emploi de Boston sur la valeur médiane des maisons occupées par leur propriétaire ?
#
# À l'aide des graphiques et diagrammes appropriés, générez des statistiques de base et des visualisations qui, selon vous, seront utiles à la direction générale pour lui donner un aperçu important de la question qu'elle se pose ; dans vos graphiques, incluez une explication de chaque statistique.
#
# Les détails concernant le projet seront détaillés dans les prochaines sections de lecture.

# %% [markdown]
# ## Aperçu des tâches du projet
# Pour le scénario du projet, voici un aperçu de vos tâches. Les sections de lecture suivantes vous fourniront des instructions détaillées pour chaque tâche.
#
# Taches du projet :
#
# *   Tâche 1 : Familiarisez-vous avec l'ensemble de données
# *   Tâche 2 : (Facultatif) Si vous ne disposez pas encore d'une instance de Watson Studio, créez un compte IBM Cloud Lite et provisionnez une instance de Waston Studio.
# *   Tâche3 : Chargez l'ensemble de données dans un carnet Jupyter à l'aide de Watson Studio.
# *   Tâche4 : Générez des statistiques et des visualisations de base pour la haute direction.
# *   Tâche5 : Utilisez les tests appropriés pour répondre aux questions fournies.
# *   Tâche6: Partagez votre carnet Jupyter.
#
#
# Ce projet représente 15 % de votre note finale. Vous trouverez ci-dessous des instructions détaillées pour chacune de ces tâches.

# %% [markdown]
# *Pour la version Google Colab du projet, la tâche 2 est sautée*

# %% [markdown]
# .

# %% [markdown]
# ## Tâche 1 : Se familiariser avec le jeu de données
#
# L'ensemble de données "Boston House Prices" contient des informations sur différentes propriétés immobilières à Boston et l'objectif est de prédire la valeur médiane des maisons (en milliers de dollars) dans ces quartiers en fonction de diverses caractéristiques. Chacune des observations correspond à un **quartier** qui est décrite par un ensemble de caractéristiques.
#
# Les variables de l'ensemble de données sont décrites ci-dessous :
#
# 1.   CRIM - taux de criminalité par habitant et par ville
# 2.   ZN - proportion de terrains résidentiels zonés pour des lots de plus de 25 000 pieds carrés.
#
# 1.   INDUS - proportion d'acres d'entreprises autres que de vente au détail par ville.
# 2.   CHAS - Variable muette Charles River (1 si la parcelle longe la rivière ; 0 sinon)
#
# 1.   NOX - concentration d'oxydes nitriques (parties par 10 millions)
# 2.   RM - nombre moyen de pièces par logement
#
# 1.   AGE - proportion de logements occupés par leur propriétaire et construits avant 1940
# 2.   DIS - distances pondérées par rapport à cinq centres d'emploi de Boston
#
# 1.   RAD - indice d'accessibilité aux autoroutes radiales
# 2.   TAX - taux d'imposition sur la pleine valeur de la propriété pour 10 000 dollars
#
# 1.   PTRATIO - taux d'encadrement par ville
# 2.   LSTAT - % de la population ayant un statut inférieur
#
# 1.   MEDV - Valeur médiane des maisons occupées par leur propriétaire en milliers de dollars
#
#
# Ces données ont été modifiées pour ce cours et le lien vers l'ensemble des données se trouve dans la bibliothèque [sklearn.datasets](https://scikit-learn.org/0.15/modules/generated/sklearn.datasets.load_boston.html).

# %% [markdown]
# .

# %% [markdown]
# ## Tâche 3 : Chargez l'ensemble de données dans votre Jupyter Notebook

# %% [markdown]
# #### Chargement des librairies

# %% [markdown]
# ##### TRÈS IMPORTANT : Google Colab ne dispose pas nativement de Conda ni de Mamba comme gestionnaire de packages. D'ailleurs, il n'est pas possible d'installer directement Conda, il faut utiliser une version modifiée. Il est donc nécessaire d'installer conda via Pip pour ensuite installer Mamba avec Conda. Le redémarrage de l'environnement d'exécution (Kernel) peut s'avérer nécessaire après l'installation de Conda et de Mamba.

# %%
#Le "-q" indique de générer une sortie "silencieuse" (quiet). Il y a donc moins de lignes dans la sortie.
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:21
# 🔁 Restarting kernel...

# %%
# Le "-c" dans la commande indique à conda qu'il doit utiliser le canal "Conda Forge" pour installer Mamba

# !conda install -c conda-forge mamba -q
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.11.17 |       hbcca054_0         151 KB  conda-forge
#     certifi-2023.11.17         |     pyhd8ed1ab_0         155 KB  conda-forge
#     openssl-3.2.0              |       hd590300_1         2.7 MB  conda-forge
#     python_abi-3.10            |          4_cp310           6 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.12.7-ha878542_0 --> 2023.11.17-hbcca054_0
#   certifi                            2022.12.7-pyhd8ed1ab_0 --> 2023.11.17-pyhd8ed1ab_0
# ...

# %%
#install specific version of libraries used in lab

#Les erreurs proviennent du fait qu'il s'agit de versions spécifiques des librairies et qu'elles ont des erreurs de dépendances avec cudatoolkit.
    # Cela n'empêche néanmoins pas le bon déroulement du projet. Ce Cudatoolkit permet d'accélérer le traitement de données, mais pour ce projet, ce n'est pas nécessaire.
! mamba install -q pandas==1.3.3
! mamba install -q numpy=1.21.2
! mamba install -q scipy=1.7.1-y
! mamba install -q seaborn=0.9.0-y
! mamba install -q matplotlib=3.4.3-y
! mamba install -q statsmodels=0.12.0-y
# Out:
# No package can be installed for pin: cudatoolkit 12.2.*
#
# # >>>>>>>>>>>>>>>>>>>>>> ERROR REPORT <<<<<<<<<<<<<<<<<<<<<<
#
#     Traceback (most recent call last):
#       File "/usr/local/lib/python3.10/site-packages/conda/exceptions.py", line 1124, in __call__
#         return func(*args, **kwargs)
#       File "/usr/local/lib/python3.10/site-packages/mamba/mamba.py", line 941, in exception_converter
#         raise e
#       File "/usr/local/lib/python3.10/site-packages/mamba/mamba.py", line 934, in exception_converter
#         exit_code = _wrapped_main(*args, **kwargs)
#       File "/usr/local/lib/python3.10/site-packages/mamba/mamba.py", line 892, in _wrapped_main
#         result = do_call(parsed_args, p)
#       File "/usr/local/lib/python3.10/site-packages/mamba/mamba.py", line 754, in do_call
#         exit_code = install(args, parser, "install")
#       File "/usr/local/lib/python3.10/site-packages/mamba/mamba.py", line 547, in install
#         solver.add_pin(final_spec)
# ...

# %% [markdown]
# ### Chargement des données

# %%
# Charger les librairies
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)

# %% [markdown]
# .

# %% [markdown]
# ## Tâche 4 : Générer des statistiques descriptives et des visualisations
#
# Pour toutes les visualisations, veuillez inclure un titre dans chaque graphique et des étiquettes appropriées
#
# Créez les graphiques suivants et expliquez vos résultats :
#
#
#
# *   Pour la "Valeur médiane des logements occupés par leur propriétaire", fournissez un diagramme en boîte
# *   Fournissez un diagramme à barres pour la variable Charles river
#
# *   Fournissez un diagramme en boîte pour la variable MEDV par rapport à la variable AGE. (Discrétisez la variable âge en trois groupes : 35 ans et moins, entre 35 et 70 ans et 70 ans et plus)
# *   Fournissez un diagramme de dispersion pour montrer la relation entre les concentrations d'oxyde nitrique et la proportion d'hectares de commerces autres que de détail par ville. Que pouvez-vous dire de cette relation ?
#
# *   Créez un histogramme pour la variable "ratio élèves/enseignants"

# %% [markdown]
# ### Valeur médiane des logements occupés par leur propriétaire

# %%
ax = sns.boxplot(x = 'MEDV', data=boston_df)

#Calculer la médiane
median = boston_df['MEDV'].median()

#Ajouter une ligne pour mettre en évidence la médiane
ax.axvline(median, color='red', linestyle='dashed', linewidth=2, label='Median')

# Ajouter la valeur de la médiane au graphique
plt.text(median + 7, 0.45, f'Median: {median}', color='red', fontsize=12,
         ha='center', va='center', rotation='horizontal', backgroundcolor='white')

#Ajouter un titre et modifier les étiquettes
plt.title('Value distribution of owner-occupied homes')
plt.xlabel('Value of owner-occupied homes in $1000s')

plt.legend()
plt.show

print("This chart shows the distribution of median home values across Boston neighborhoods. This data shows that the median value is $21,200")
# Out:
# This chart shows the distribution of median home values across Boston neighborhoods. This data shows that the median value is $21,200

# %% [markdown]
# ### Diagramme à barres pour la variable Charles river

# %%
# Calculer la valeur médiane des habitations en fonction de leur catégorie : quelle soit ou non sur le bord de la rivière
division_eval = boston_df.groupby('CHAS')[['MEDV']].median().reset_index()

# Calculer le graphique
ax = sns.barplot(x = 'CHAS', y='MEDV', data=division_eval, palette=['green', 'blue'])

# Ajouter titre au graphiques et aux axes
plt.title('Median Value of Houses Whether They Are on the Charles River Bank or Not')
plt.xlabel('Location in relation to the river')
plt.ylabel('Value of houses in $1000s')

# Modifier la gradation des axes
plt.xticks([0, 1], ['Not on the river bank', 'On the river bank'])
plt.yticks([0, 5, 10, 15, 20, 25], ['0', '5', '10', '15', '20', '25'])

# Type de graphique, légende et présentation
sns.set(style="whitegrid")
plt.show()

print("This chart shows the median value of homes in Boston based on whether \nthey are on the banks of the Charles River or not. Houses near the river are more expensive.")
# Out:
# This chart shows the median value of homes in Boston based on whether
# they are on the banks of the Charles River or not. Houses near the river are more expensive.

# %% [markdown]
# ### Diagramme en boîte pour la variable MEDV par rapport à la variable AGE

# %%
# On va refaire les catégories, mais d'une manière différente.

# Une première catégorie sera les quartiers qui ont de 0% à 25% de logements construits avant 1940 et qui sont habité par leur propriétaire
boston_df.loc[(boston_df['AGE'] >= 0) & (boston_df['AGE'] <= 25), 'age_group'] = '0% to 25%'

# Une deuxième catégorie sera les quartiers qui ont de 25 à 50% de logements construits avant 1940 et qui sont habité par leur propriétaire
boston_df.loc[(boston_df['AGE'] > 25) & (boston_df['AGE'] <= 50), 'age_group'] = '25% to 50%'

# Une troisième catégorie sera les quartiers qui ont de 50 à 75% de logements construits avant 1940 et qui sont habité par leur propriétaire
boston_df.loc[(boston_df['AGE'] > 50) & (boston_df['AGE'] <= 75), 'age_group'] = '50% to 75%'

# Une quatrième catégorie sera les quartiers qui ont de 75% à 100% de logements construits avant 1940 et qui sont habité par leur propriétaire
boston_df.loc[(boston_df['AGE'] > 75) & (boston_df['AGE'] <= 100), 'age_group'] = '75% to 100%'

#Calculer le graphique
ax = sns.boxplot(x = 'age_group', y = 'MEDV', data = boston_df, order=['0% to 25%', '25% to 50%', '50% to 75%', '75% to 100%'])

# Ajouter titre au graphiques et aux axes
plt.title('Median home values of Boston neighborhoods\nby age group in those neighborhoods')
plt.xlabel('Proportion of properties built before 1940')
plt.ylabel('Median property value in $1000s')

plt.show()
print('')
print('Among neighborhoods with 0% to 25% of properties built before 1940, the value of 50% of these properties range between ~23k and ~31k')
print('Among neighborhoods with 25% to 50% of properties built before 1940, the value of 50% of these properties range between ~21k et ~30k')
print('Among neighborhoods with 50% to 75% of properties built before 1940, the value of 50% of these properties range between ~20k et ~27k')
print('Among neighborhoods with 75% to 100% of properties built before 1940, the value of 50% of these properties range between ~14k et ~22k')
print('')
print("This graph suggests that as neighborhoods age, home values decline.")
# Out:
# Among neighborhoods with 0% to 25% of properties built before 1940, the value of 50% of these properties range between ~23k and ~31k
# Among neighborhoods with 25% to 50% of properties built before 1940, the value of 50% of these properties range between ~21k et ~30k
# Among neighborhoods with 50% to 75% of properties built before 1940, the value of 50% of these properties range between ~20k et ~27k
# Among neighborhoods with 75% to 100% of properties built before 1940, the value of 50% of these properties range between ~14k et ~22k
#
# This graph suggests that as neighborhoods age, home values decline.

# %% [markdown]
# ### Diagramme de dispersion pour montrer la relation entre les concentrations d'oxyde nitrique et la proportion d'hectares de commerces autres que de détail par ville

# %%
# Calculer le graphique
ax = sns.scatterplot(x='INDUS', y='NOX', data=boston_df, s=50, color='green')

# Ajouter une ligne de régression
sns.regplot(x='INDUS', y='NOX', data=boston_df, scatter=False, ax=ax)

# Ajouter titre au graphiques et aux axes
plt.title('Nitric oxides concentration (parts per 10 million)\n by proportion of non-retail business acres per town', fontsize=16)
plt.xlabel('Proportion of non-retail business acres per town', fontsize=12)
plt.ylabel('Nitric oxides concentration', fontsize=12)

# Personnaliser les axes
ax.tick_params(axis='both', which='both', labelsize=10)

# Présenter le graphique
plt.show()

print("This graph shows a positive and growing relationship between nitric oxide concentration versus proportion of non-retail hectares by city.")
# Out:
# This graph shows a positive and growing relationship between nitric oxide concentration versus proportion of non-retail hectares by city.

# %% [markdown]
# ### Histogramme pour la variable "ratio élèves/enseignants"

# %%
# Calculer le graphique
ax = sns.distplot(boston_df['PTRATIO'], kde=False)

# Ajouter titre au graphiques et aux axes
plt.title('Pupil-teacher ratio by town', fontsize=16)
plt.xlabel('pupil-teacher ratio', fontsize=12)
plt.ylabel('Number of town (Frequency)', fontsize=12)

# Personnaliser les axes
ax.tick_params(axis='both', which='both', labelsize=10)

# Présenter le graphique
plt.show()
# Out:
# <ipython-input-12-bf776d349ddf>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(boston_df['PTRATIO'], kde=False)

# %% [markdown]
# ## Tâche 5 : Utilisez les tests appropriés pour répondre aux questions fournies
#
# Pour chacune des questions suivantes :
#
# 1.   Existe-t-il une différence significative dans la valeur médiane des maisons bordées par la rivière Charles ou non ? (Test T pour les échantillons indépendants)
# 2.   Y a-t-il une différence dans les valeurs médianes des maisons (MEDV) pour chaque proportion d'unités occupées par le propriétaire et construites avant 1940 (AGE) ? (ANOVA)
#
# 1.   Peut-on conclure qu'il n'y a pas de relation entre les concentrations d'oxyde nitrique et la proportion d'hectares de commerces autres que de détail par ville (corrélation de Pearson) ?
# 2.   Quel est l'impact d'une distance pondérée supplémentaire par rapport aux cinq centres d'emploi de Boston sur la valeur médiane des maisons occupées par leur propriétaire ? (Analyse de régression)
#
#
# Veillez à :
#
# 1.   Énoncer votre hypothèse.
# 2.   Utiliser α = 0,05
#
# 1.   Effectuez le test statistique.
# 2.   Énoncez la conclusion du test.

# %% [markdown]
# ### Existe-t-il une différence significative dans la valeur médiane des maisons bordées par la rivière Charles ou non? (Test T pour les échantillons indépendants)

# %%
print("H0 : There is no statistically significant difference in the median value of homes on or off the Charles River.")
print("H1 : There is a statistically significant difference in the median value of homes on or off the Charles River.")

#Tester la variance avec un test de Levene
levene_statistic, levene_pvalue = sp.stats.levene(boston_df[boston_df['CHAS'] == 0]['MEDV'],
                                                  boston_df[boston_df['CHAS'] == 1]['MEDV'], center = 'mean')

#Faire le t test en adéquation avec le résultat précédent
t_statistic, t_pvalue = sp.stats.ttest_ind(boston_df[boston_df['CHAS'] == 0]['MEDV'],
                                           boston_df[boston_df['CHAS'] == 1]['MEDV'], equal_var = False)

print('')
print("Levene Test p-value :", levene_pvalue)
print("Welch T Test p-value :", t_pvalue)
print('')
print("Since the p-value of the T test is less than 0.05, it is possible to reject the null hypothesis (HO) and \nsuggest that houses on the banks of the Charles River are more expensive than houses that aren't.")
# Out:
# H0 : There is no statistically significant difference in the median value of homes on or off the Charles River.
# H1 : There is a statistically significant difference in the median value of homes on or off the Charles River.
#
# Levene Test p-value : 0.003238119367639829
# Welch T Test p-value : 0.003567170098137517
#
# Since the p-value of the T test is less than 0.05, it is possible to reject the null hypothesis (HO) and
# suggest that houses on the banks of the Charles River are more expensive than houses that aren't.

# %% [markdown]
# ### Y a-t-il une différence dans les valeurs médianes des maisons (MEDV) pour chaque proportion d'unités occupées par le propriétaire et construites avant 1940 (AGE)? (ANOVA)

# %%
print("H0 : There is no statistically significant difference in median home values by the proportion of owner-occupied units built before 1940")
print("H1 : There is a statistically significant difference in median home values by the proportion of owner-occupied units built before 1940")

# Création des groupes

# Une première catégorie sera les quartiers qui ont de 0% à 25% de logements construits avant 1940 et qui sont habité par leur propriétaire
boston_df.loc[(boston_df['AGE'] >= 0) & (boston_df['AGE'] <= 25), 'age_group'] = '0% to 25%'

# Une deuxième catégorie sera les quartiers qui ont de 25 à 50% de logements construits avant 1940 et qui sont habité par leur propriétaire
boston_df.loc[(boston_df['AGE'] > 25) & (boston_df['AGE'] <= 50), 'age_group'] = '25% to 50%'

# Une troisième catégorie sera les quartiers qui ont de 50 à 75% de logements construits avant 1940 et qui sont habité par leur propriétaire
boston_df.loc[(boston_df['AGE'] > 50) & (boston_df['AGE'] <= 75), 'age_group'] = '50% to 75%'

# Une quatrième catégorie sera les quartiers qui ont de 75% à 100% de logements construits avant 1940 et qui sont habité par leur propriétaire
boston_df.loc[(boston_df['AGE'] > 75) & (boston_df['AGE'] <= 100), 'age_group'] = '75% to 100%'


# Test de Levene pour voir s'il y a une différence statistiquement significative des variances.
levene_statistic, levene_pvalue = sp.stats.levene(boston_df[boston_df['age_group'] == '0% to 25%']['MEDV'],
                                                  boston_df[boston_df['age_group'] == '25% to 50%']['MEDV'],
                                                  boston_df[boston_df['age_group'] == '50% to 75%']['MEDV'],
                                                  boston_df[boston_df['age_group'] == '75% to 100%']['MEDV'],
                                                  center = 'mean')

# Séparer les groupes (un pour chaque catégorie) en variable unique
twentyfive_lower   = boston_df[boston_df['age_group'] == '0% to 25%']['MEDV']
twentyfive_fifty   = boston_df[boston_df['age_group'] == '25% to 50%']['MEDV']
fifty_seventyfive  = boston_df[boston_df['age_group'] == '50% to 75%']['MEDV']
seventyfive_hundred= boston_df[boston_df['age_group'] == '75% to 100%']['MEDV']

# Test Anova
f_statistic, f_pvalue = sp.stats.f_oneway(twentyfive_lower, twentyfive_fifty, fifty_seventyfive, seventyfive_hundred)

print('')
print("Levene Test p-value :", levene_pvalue)
print("Anova Test p-value :", f_pvalue)
print('')
print("Since the p-value of the Anova test is less than 0.05, it is possible to reject the null hypothesis (H0) and suggest that \nthere is a statistically significant difference in the median house values depending on the proportion of owner-occupied \nunits built before 1940.")
# Out:
# H0 : There is no statistically significant difference in median home values by the proportion of owner-occupied units built before 1940
# H1 : There is a statistically significant difference in median home values by the proportion of owner-occupied units built before 1940
#
# Levene Test p-value : 0.28139170079967424
# Anova Test p-value : 2.137213473971852e-15
#
# Since the p-value of the Anova test is less than 0.05, it is possible to reject the null hypothesis (H0) and suggest that
# there is a statistically significant difference in the median house values depending on the proportion of owner-occupied
# units built before 1940.

# %% [markdown]
# ### Peut-on conclure qu'il n'y a pas de relation entre les concentrations d'oxyde nitrique et la proportion d'hectares de commerces autres que de détail par ville (corrélation de Pearson) ?

# %%
print("H0 : There is no statistically significant relationship between nitric oxide concentrations and the proportion of non-retail hectares by city")
print("H1 : There is a statistically significant relationship between nitric oxide concentrations and the proportion of non-retail hectares by city")
print('')

# Calculer le graphique
ax = sns.scatterplot(x='INDUS', y='NOX', data=boston_df, s=50, color='green')
plt.show()

# Test de corrélation
statistic, pvalue = sp.stats.pearsonr(boston_df['INDUS'], boston_df['NOX'])

print('')
print("Pearson Test p-value :", pvalue)
print('')
print("Since the p-value of the Pearson test is less than 0.05, it is possible to reject the null hypothesis (H0) and\nsuggest that there is a statistically significant relationship between nitric oxide concentrations and the proportion\nhectares of non-retail businesses per city.")
# Out:
# H0 : There is no statistically significant relationship between nitric oxide concentrations and the proportion of non-retail hectares by city
# H1 : There is a statistically significant relationship between nitric oxide concentrations and the proportion of non-retail hectares by city
# Pearson Test p-value : 7.913361061239527e-98
#
# Since the p-value of the Pearson test is less than 0.05, it is possible to reject the null hypothesis (H0) and
# suggest that there is a statistically significant relationship between nitric oxide concentrations and the proportion
# hectares of non-retail businesses per city.

# %% [markdown]
# ### Quel est l'impact d'une distance pondérée supplémentaire par rapport aux cinq centres d'emploi de Boston sur la valeur médiane des maisons occupées par leur propriétaire ? (Analyse de régression)

# %%
print("H0 : There is no relationship between the weighted distance to five Boston employment centers and the median value of owner-occupied homes.")
print("H1 : There is a relationship between the weighted distance to five Boston employment centers and the median value of owner-occupied homes.")
print("")

ax = sns.scatterplot(x='DIS', y='MEDV', data=boston_df, s=50, color='red')
plt.show()

# Identification de la variable indépendante
X = boston_df['DIS']

# Identification de la variable dépendante
y = boston_df['MEDV']

# Ajouter une constante au modèle
X = sm.add_constant(X)

# Calculer le modèle
model = sm.OLS(y, X).fit()
predictions = model.predict(X)

# Présentation des résultats
print(model.summary())

print('')
print("Since the p-value of the regression analysis is less than 0.05, it is possible to reject the null hypothesis (H0) \nand suggest that there is a statistically significant relationship between the weighted distance from five Boston \nemployment centers and the median value of owner-occupied homes.")
print('')
print("For a one unit increase in the DIS variable, the MEDV variable will increase on average by 1.09 units.")
print('')
print("In other words, an increase of one mile in the weighted distance from the \nfive employment centers in Boston will, on average, result in a $1,090 \nincrease in the median value of owner-occupied homes.")
# Out:
# H0 : There is no relationship between the weighted distance to five Boston employment centers and the median value of owner-occupied homes.
# H1 : There is a relationship between the weighted distance to five Boston employment centers and the median value of owner-occupied homes.
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Fri, 12 Jan 2024   Prob (F-statistic):           1.21e-08
# Time:                        19:49:10   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ## Tâche 6 (Facultatif) : Partagez votre Jupyter Notebook
#
# Suivre les indications [suivantes](https://author-ide.skills.network/render?token=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..cw_i-HliyH4sxsZzCCQTH0akQa1D9frhrweDoY2QWos).
